# %%
# Importing the Python Library: pandas
# pandas is used as a data analysis and manipulation tool.
# For detailed info on pandas, please go to the website https://pandas.pydata.org/
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

# %%
# Reading the csv file of Import-mod.csv data
#imports_data = pd.read_csv("C:/Keras/imports-mod.csv")
#imports_data.head()
imports_data_path = "./Dataset/imports-mod.csv"
imports_data = pd.read_csv(imports_data_path)

# %%
imports_data.head()
# Out:
#    Unnamed: 0  symboling normalized-losses    make fuel-type aspiration  \
# 0           1          0                 ?  jaguar       gas        std
# 1           2          3               194  nissan       gas        std
# 2           3          0                 ?  peugot    diesel      turbo
# 3           4          0                85   honda       gas        std
# 4           5          0               108  nissan       gas        std
#
#   num-of-doors body-style drive-wheels engine-location  ...  fuel-system  \
# 0          two      sedan          rwd           front  ...         mpfi
# 1          two  hatchback          rwd           front  ...         mpfi
# 2         four      wagon          rwd           front  ...          idi
# 3         four      sedan          fwd           front  ...         1bbl
# 4         four      sedan          fwd           front  ...         mpfi
#
#    bore  stroke  compression-ratio  horsepower peak-rpm city-mpg  highway-mpg  \
# ...

# %%
# Get the shape of Import-mod.csv data
print("Shape of Import-mod data:",imports_data.shape)
# Out:
# Shape of Import-mod data: (205, 28)

# %%
# Get the columns of the datasets

imports_data.columns
# Out:
# Index(['Unnamed: 0', 'symboling', 'normalized-losses', 'make', 'fuel-type',
#        'aspiration', 'num-of-doors', 'body-style', 'drive-wheels',
#        'engine-location', 'wheel-base', 'length', 'width', 'height',
#        'curb-weight', 'engine-type', 'num-of-cylinders', 'engine-size',
#        'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower',
#        'peak-rpm', 'city-mpg', 'highway-mpg', 'price', 'date'],
#       dtype='object')

# %%
# Statistical summary about the dataset
imports_data.describe()
# Out:
#        Unnamed: 0   symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# ...

# %%
#checks out how many null info are on the dataset
imports_data.isnull().sum()
# Out:
# Unnamed: 0           0
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# date                 0
# dtype: int64

# %%
# How to check for data types in python
imports_data.dtypes
# Out:
# Unnamed: 0             int64
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# date                  object
# dtype: object

# %%
# Convert the column "date" & "price" into datetime format

imports_data['date'] = pd.to_datetime(imports_data['date'])
#imports_data['price'] = pd.to_numeric(imports_data['price'])
imports_data['price'][50:60]
# Out:
# 50     9549
# 51     6795
# 52     5572
# 53    13495
# 54        ?
# 55        ?
# 56    35550
# 57     6785
# 58     5572
# 59     6692
# Name: price, dtype: object

# %%
# Making a data frame for price and date column only
price_date1 = imports_data.loc[:, ['price', 'city-mpg']]
price_date1

# scatter_matrix(imports_data,figsize=(14,14))
# plt.show()
# Out:
#      price  city-mpg
# 0    36000        13
# 1    17199        19
# 2    17075        25
# 3     8845        27
# 4    13499        19
# ..     ...       ...
# 200  13415        23
# 201   7898        34
# 202  16630        19
# 203  28248        22
# 204   8249        31
#
# [205 rows x 2 columns]

# %%
# scatter plot matrix of price and date columns 
pd.plotting.scatter_matrix(price_date1)
plt.show()

# %%
# Again check for data types in python
#imports_data.dtypes

# %%
# Making a data frame for price and date column only
import_subdata = imports_data.loc[:, ['compression-ratio','city-mpg', 'highway-mpg']]
import_subdata
# Out:
#      compression-ratio  city-mpg  highway-mpg
# 0                 11.5        13           17
# 1                  9.0        19           25
# 2                 21.0        25           25
# 3                  9.0        27           33
# 4                  9.0        19           25
# ..                 ...       ...          ...
# 200                9.5        23           28
# 201               22.5        34           36
# 202                8.4        19           24
# 203               21.5        22           25
# 204                9.4        31           37
#
# [205 rows x 3 columns]

# %%
# scatter plot matrix of price and date columns 
pd.plotting.scatter_matrix(import_subdata)
plt.show()
